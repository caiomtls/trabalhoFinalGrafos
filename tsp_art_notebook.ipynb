# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioMatheu5/trabalhoFinalGrafos/blob/main/tsp_art_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/matthras/tsp-art-python.git
# Out:
# Cloning into 'tsp-art-python'...
# remote: Enumerating objects: 203, done.
# remote: Total 203 (delta 0), reused 0 (delta 0), pack-reused 203
# Receiving objects: 100% (203/203), 1.51 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (100/100), done.

# %%
# !ls
# Out:
# sample_data  tsp-art-python

# %%
# !pip install -r '/content/tsp-art-python/requirements.txt'
# Out:
# ...
#      |████████████████████████████████| 14.5 MB 91 kB/s
# ...
#      |████████████████████████████████| 126 kB 58.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 39.4 MB/s
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.4.0 requires absl-py<0.13,>=0.9, but you have absl-py 1.0.0 which is incompatible.
# ...

# %%
# %cd /content/tsp-art-python/
# Out:
# /content/tsp-art-python

# %%
# !python stippling.py
# Out:
# Number of points: 1024
# Number of iterations: 25
# PNG: images/smileyface-inverted-1024-stipple.png
# TSP: images/smileyface-inverted-1024-stipple.tsp
# 100% 25/25 [00:17<00:00,  1.47it/s]

# %%
# !python draw-tsp-path.py
# Out:
# Step 1/5: Initialising variables
# Step 2/5: Computing distance matrix
# Step 3/5: Setting an initial solution
# Step 4/5: Solving
# Step 5/5: Drawing the solution
# TSP solution has been drawn and can be viewed at images/smileyface-inverted-1024-tsp.png
